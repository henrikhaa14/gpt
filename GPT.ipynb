# %% [markdown]
# <a href="https://colab.research.google.com/github/henrikhaa14/gpt/blob/main/GPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/henrikhaa14/gpt.git
# !python gpt/train.py
# Out:
# Cloning into 'gpt'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 5 (delta 1), reused 5 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (5/5), 4.89 KiB | 4.89 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# 📚 Loading data...
# Traceback (most recent call last):
#   File "/content/gpt/train.py", line 48, in <module>
#     with open(INPUT_FILE, 'r', encoding='utf-8', errors='ignore') as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'inputs/tiny-shakespeare.txt'
